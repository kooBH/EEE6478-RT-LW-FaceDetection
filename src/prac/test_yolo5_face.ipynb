# %%
import sys
sys.path.append("./yolo5-face")
from detect_face import run
import numpy as np

import matplotlib.pylab as plt
import matplotlib.image as img

import IPython.display as ipd
import matplotlib
matplotlib.use('TkAgg')
# %matplotlib inline

import cv2

# %%
image_path = "../sample/WIDERFACE/9_Press_Conference_Press_Conference_9_108.jpg"

# %%
y = run("../pretrained/yolov5m-face.pt",image_path,"cuda:0")
# Out:
# Fusing layers...
# img.shape:  torch.Size([1, 3, 672, 800])
# orgimg.shape:  (835, 1024, 3)

# %%
y1 = cv2.cvtColor(y, cv2.COLOR_BGR2RGB)
plt.imshow(y1)
plt.show()
